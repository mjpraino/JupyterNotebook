# %% [markdown]
# <h1> My Jupyter Notebook on IBM Data Science Experience</h1>

# %% [markdown]
# <b>My name is Matthew</b> <br>
# <p>My current occupation is an IT Operations Analyst, my desired occupation <br> would be and IT Data Analyst or a Web/App Developer/Manager.

# %% [markdown]
# <em>I am interested in Data Science because it brings importance to companies. <br>
#     It provides data driven information so companies can learn and understand<br>
#     the trending patterns created from their own business. These fields of<br>
#     research provide meaning, challenge and a unique expertise. Data Science <br>
#     isn't just cool to get into, it is the future, i want to be part of the future.</em>

# %% [markdown]
# <h3>Im going to Import Chance with Python and create a Die roll and coin flip we can just call the function</h3>

# %%
import random

def coin_flip():
    return random.choice(['heads', 'tails'])

def die_roll():
    return random.randint(1,6)
die_roll()
coin_flip()
# Out:
# 'tails'

# %% [markdown]
# <html lang = "en">
# <head>
#     <h3>This is cell 6</h3>
#     <title>This is the work for cell 6</title>
#     </head>
#       <body>
#         <p>
#           <ol><em>Here is a heading for the list with italics</em><hr>
#                 <li>Here is a list</li>
#                 <li>And one more</li>
#           </ol>
#           <ul><strong>This is a heading for the bullets with bold</strong><hr>
#                 <li>Here is a bullet list</li>
#               <li><strike>This is another bullet with a strikethrough</strike></li>
#           <ul>
#         </p>
#     </body>
#     <body>
#        <p>Here is a google.com hyperlink
#            <a ref = "https://www.google.com">Google</a>
#         <img src="https://placebear.com/300/200" alt="This is a picture of a bear.">
#         <img src="https://placekitten.com/300/200" alt="This is a picture of a kitten.">
#         <table style = "width:100%">
#             <tr>
#                 <th>Matthew</th>
#                 <th>Praino</th>
#                 <th>25</th>
#             </tr>
#             <blockquote>
#                 <p>"This is a blockquote"</p>
#                 <footer>Matt</footer>
#             </blockquote>
#         </p>
#     </body>
#   </html>
